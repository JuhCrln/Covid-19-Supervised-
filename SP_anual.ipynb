# %%
import numpy as np
import numpy
import pandas as pd
from pandas import read_csv
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # SP 2022

# %%
# load data
#SP_20_22 = read_csv('filtered_df_SP_final.csv', delimiter=",", low_memory=False, keep_default_na=False)

# %%
#SP_22 = SP_20_22[SP_20_22['year'] == 2022]

# %%
#tirar coluna 'Unnamed'
#SP_22 = SP_22.drop(SP_22.columns[0], axis=1)

# %%
#SP_22

# %%
#SP_22.to_csv("SP_22.csv")

# %% [markdown]
# # SP 2020

# %%
SP_20 = SP_20_22[SP_20_22['year'] == 2020]

# %%
SP_20 = SP_20.drop(SP_20.columns[0], axis=1)

# %%
#SP_20
# Out:
#        SG_UF_NOT  month  year  DESC_RESP  DIARREIA  DISPNEIA  DOR_ABD  FADIGA  \
# 3             SP      1  2020          1         2         1        0       0
# 4             SP      1  2020          1         2         2        0       0
# 5             SP      1  2020          1         2         1        0       0
# 6             SP      1  2020          2         2         1        0       0
# 7             SP      1  2020          1         2         1        0       0
# ...          ...    ...   ...        ...       ...       ...      ...     ...
# 302071        SP     12  2020          1         1         2        2       2
# 302072        SP     12  2020          2         2         2        2       2
# 302073        SP     12  2020          1         2         1        2       1
# 302074        SP     12  2020          1         2         1        2       1
# 302075        SP     12  2020          2         2         2        1       2
#
# ...

# %%
SP_20.to_csv("SP_20.csv")

# %% [markdown]
# # SP 2021

# %%
#SP_21 = SP_20_22[SP_20_22['year'] == 2021]

# %%
#SP_21 = SP_21.drop(SP_21.columns[0], axis=1)

# %%
#SP_21

# %%
#SP_21.to_csv("SP_21.csv")
